# %% [markdown]
# # Tokenizer Little Duck
#
# Notebook de ejecucion para la actividad 3.2. Clona el repositorio, entra a la carpeta de la actividad y ejecuta los casos de prueba.

# %%
# !git clone https://github.com/garrza/compi-acts.git
# %cd compi-acts/3.2-algoritmodetokenizacion
# !python3 run_casos.py

# %% [markdown]
# Para ejecutar un archivo especifico, cambia la ruta del siguiente comando.

# %%
# !python3 patokenizer.py casos-prueba/factorial.txt
